# %%
import random

class NakliLLM: 

   def __init__(self):
    print('LLM start')

   def predict(self, prompt):

      response_list = [
        'Mumbai is Capital of Maharashtra'
        'Hero ISL is a Foodball leage',
        'AI stand for Artificial Intelligence'
      ] 

      return {"response": random.choice(response_list)}

llm = NakliLLM()
# Out:
# LLM start

# %%
llm.predict('What is the Capital of Maharashtra')
# Out:
# {'response': 'Mumbai is Capital of MaharashtraHero ISL is a Foodball leage'}

# %%
class NakliPromptTemplate:

    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables

    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template = "Write a poem about {topic}",
    input_variables = ['topic']
)

# %%
template.format({'topic':'india'})
# Out:
# 'Write a poem about india'
